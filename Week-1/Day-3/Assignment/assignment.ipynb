# %% [markdown]
# # Tasks for Learning Logistic Regression
#
# ## 1. Dataset Exploration and Understanding:
#
# - **Task:** Load your dataset into your preferred environment (e.g., Python with pandas).
# - **Steps:**
#   - Explore the structure of the dataset (number of samples, features, target variable).
#   - Check for any missing values and handle them appropriately (e.g., imputation or removal).

# %%
import pandas as pd
df=pd.read_csv('./Titanic-Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Handle missing values (for example, fill missing ages with the mean)
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# Encode categorical variables
df = pd.get_dummies(df, columns=['Sex', 'Embarked'], drop_first=True)

# Define features (X) and target variable (y)
features = ['Pclass', 'Sex_male', 'Age', 'SibSp',
            'Parch', 'Fare', 'Embarked_Q', 'Embarked_S']
X_train = df[features]
y_train = df['Survived']

# %% [markdown]
# - **Task:** Perform Logistic Regression from Scratch

# %%
import numpy as np


def sigmoid(z):
    """
    Compute the sigmoid of z

    Args:
        z (ndarray): A scalar, numpy array of any size.

    Returns:
        g (ndarray): sigmoid(z), with the same shape as z
         
    """

    g = 1/(1+np.exp(-z))

    return g
def cost_function(X,y,w,b,lambda_):
    m=X_train.shape[0]
    for i in range(m):
        z_i = np.dot(X[i], w) + b  # (n,)(n,)=scalar, see np.dot
        f_wb_i = sigmoid(z_i)  # scalar
        cost += -y[i]*np.log(f_wb_i) - (1-y[i])*np.log(1-f_wb_i)
    cost/=m
    reg_cost = 0
    for j in range(n):
        reg_cost += (w[j]**2)  # scalar
    reg_cost = (lambda_/(2*m)) * reg_cost
    total_cost = cost + reg_cost  # scalar
    return total_cost

# %%
import numpy as np

# Sigmoid function


def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Regularized cost function for logistic regression


def cost_function(X, y, w, b, lambda_val):
    m = X.shape[0]
    z = np.dot(X, w) + b
    y_pred = sigmoid(z)

    # Compute log loss (binary cross-entropy)
    epsilon = 1e-15  # Small value to prevent log(0) issues
    cost = -np.mean(y * np.log(y_pred + epsilon) + (1 - y)
                    * np.log(1 - y_pred + epsilon))

    # Regularization term (L2 regularization)
    regularization = (lambda_val / (2 * m)) * np.sum(w**2)

    # Regularized cost function
    cost_reg = cost + regularization

    return cost_reg


# Example usage:
np.random.seed(1)
w_tmp = np.random.rand(X_train.shape[1]) - 0.5  # Initialize weights randomly
b_tmp = 0.5  # Initialize bias term
lambda_tmp = 0.7  # Regularization parameter

# Assuming X_train and y_train are your training data and labels
cost_tmp = cost_function(X_train, y_train, w_tmp, b_tmp, lambda_tmp)

print("Regularized cost:", cost_tmp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'float' object has no attribute 'exp'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 38
#      35 lambda_tmp = 0.7  # Regularization parameter
#      37 # Assuming X_train and y_train are your training data and labels
# ---> 38 cost_tmp = cost_function(X_train, y_train, w_tmp, b_tmp, lambda_tmp)
#      40 print("Regularized cost:", cost_tmp)
#
# Cell In[6], line 15, in cost_function(X, y, w, b, lambda_val)
#      13 m = X.shape[0]
#      14 z = np.dot(X, w) + b
# ---> 15 y_pred = sigmoid(z)
#      17 # Compute log loss (binary cross-entropy)
#      18 epsilon = 1e-15  # Small value to prevent log(0) issues
#
# Cell In[6], line 7, in sigmoid(z)
#       6 def sigmoid(z):
# ...

# %%
np.random.seed(1)
w_tmp = np.random.rand(X_train.shape[1]).reshape(-1,)-0.5
b_tmp = 0.5
lambda_tmp = 0.7
cost_tmp = cost_function(X_train, y_train, w_tmp, b_tmp,lambda_tmp)

print("Regularized cost:", cost_tmp)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 5
#       3 b_tmp = 0.5
#       4 lambda_tmp = 0.7
# ...
