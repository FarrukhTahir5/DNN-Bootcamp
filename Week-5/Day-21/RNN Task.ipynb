# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import math
from sklearn.preprocessing import MinMaxScaler

# %%
dataset=pd.read_csv(r'C:\Users\Farrukh\DNN-Bootcamp\Week-5\Day-21\Daily Demand Forecasting Orders.csv')
dataset.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#    Week of the month (first week, second, third, fourth or fifth week  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    Day of the week (Monday to Friday)  Non-urgent order  Urgent order  \
# 0                                   4           316.307       223.270
# 1                                   5           128.633        96.042
# 2                                   6            43.651        84.375
# 3                                   2           171.297       127.667
# 4                                   3            90.532       113.526
#
#    Order type A  Order type B  Order type C  Fiscal sector orders  \
# 0        61.543       175.586       302.448                 0.000
# 1        38.058        56.037       130.580                 0.000
# 2        21.826        25.125        82.461                 1.386
# 3        41.542       113.294       162.284                18.156
# 4        37.679        56.618       116.220                 6.459
#
#    Orders from the traffic controller sector  Banking orders (1)  \
# 0                                      65556               44914
# 1                                      40419               21399
# 2                                      11992                3452
# 3                                      49971               33703
# 4                                      48534               19646
#
#    Banking orders (2)  Banking orders (3)  Target (Total orders)
# 0              188411               14793                539.577
# 1               89461                7679                224.675
# 2               21305               14947                129.412
# 3               69054               18423                317.120
# 4               16411               20257                210.517

# %%
scaler = MinMaxScaler()
dataset[dataset.columns] = scaler.fit_transform(dataset)
dataset.columns
# Out:
# Index(['Unnamed: 0',
#        'Week of the month (first week, second, third, fourth or fifth week',
#        'Day of the week (Monday to Friday)', 'Non-urgent order',
#        'Urgent order', 'Order type A', 'Order type B', 'Order type C',
#        'Fiscal sector orders', 'Orders from the traffic controller sector',
#        'Banking orders (1)', 'Banking orders (2)', 'Banking orders (3)',
#        'Target (Total orders)'],
#       dtype='object')

# %%
dataset.head()
# Out:
#    Unnamed: 0  \
# 0    0.000000
# 1    0.016949
# 2    0.033898
# 3    0.050847
# 4    0.067797
#
#    Week of the month (first week, second, third, fourth or fifth week  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
# 3                                               0.25
# 4                                               0.25
#
#    Day of the week (Monday to Friday)  Non-urgent order  Urgent order  \
# 0                                0.50          0.696167      1.000000
# 1                                0.75          0.216983      0.127972
# 2                                1.00          0.000000      0.048006
# 3                                0.00          0.325916      0.344732
# 4                                0.25          0.119700      0.247808
#
#    Order type A  Order type B  Order type C  Fiscal sector orders  \
# 0      0.412207      0.621183      1.000000              0.000000
# 1      0.168466      0.127621      0.246444              0.000000
# 2      0.000000      0.000000      0.035466              0.001602
# 3      0.204625      0.364008      0.385450              0.020990
# 4      0.164532      0.130020      0.183483              0.007467
#
#    Orders from the traffic controller sector  Banking orders (1)  \
# 0                                   0.896019            0.200245
# 1                                   0.475527            0.086677
# 2                                   0.000000            0.000000
# 3                                   0.635313            0.146101
# 4                                   0.611275            0.078211
#
#    Banking orders (2)  Banking orders (3)  Target (Total orders)
# 0            1.000000            0.107527               0.842157
# 1            0.424709            0.000000               0.195595
# 2            0.028453            0.109855               0.000000
# 3            0.306064            0.162394               0.385405
# 4            0.000000            0.190115               0.166526

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Assuming 'dataset' is your DataFrame

# Separate features and target variable
X = dataset.drop('Target (Total orders)', axis=1).values  # Convert to NumPy array directly
y = dataset['Target (Total orders)']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Reshape for RNN input (assuming time series data)
look_back = 20  # Define your desired lookback period
X_train = np.reshape(X_train, (X_train.shape[0] - look_back, look_back, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0] - look_back, look_back, X_test.shape[1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 15
#      13 # Reshape for RNN input (assuming time series data)
#      14 look_back = 20  # Define your desired lookback period
# ---> 15 X_train = np.reshape(X_train, (X_train.shape[0] - look_back, look_back, X_train.shape[1]))
#      16 X_test = np.reshape(X_test, (X_test.shape[0] - look_back, look_back, X_test.shape[1]))
#
# File c:\Users\Farrukh\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\fromnumeric.py:285, in reshape(a, newshape, order)
#     200 @array_function_dispatch(_reshape_dispatcher)
#     201 def reshape(a, newshape, order='C'):
#     202     """
#     203     Gives a new shape to an array without changing its data.
#     204
#    (...)
#     283            [5, 6]])
#     284     """
# --> 285     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File c:\Users\Farrukh\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: cannot reshape array of size 624 into shape (28,20,13)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5812\3100351750.py in ?()
# ----> 1 X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))  # Reshape training input for RNN
#       2 X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
#
# c:\Users\Farrukh\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'
